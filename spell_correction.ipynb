# %% [markdown]
# <a href="https://colab.research.google.com/github/JayVardhan-dev/NLP_LAB/blob/main/spell_correction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from textblob import TextBlob

text = "I havv goood speling"
print(TextBlob(text).correct())
# Out:
# I have good spelling
