# %% [markdown]
# <a href="https://colab.research.google.com/github/JayVardhan-dev/NLP_LAB/blob/main/tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize

text = "Tokenization splits text into words!"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Tokenization', 'splits', 'text', 'into', 'words', '!']

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True
