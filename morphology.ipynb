# %% [markdown]
# <a href="https://colab.research.google.com/github/JayVardhan-dev/NLP_LAB/blob/main/morphology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
words = ["running", "flies", "bigger", "happily"]
print([stemmer.stem(w) for w in words])
# Out:
# ['run', 'fli', 'bigger', 'happili']
